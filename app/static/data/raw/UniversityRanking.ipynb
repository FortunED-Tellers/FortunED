# %%
import pandas as pd

# %%
uniRank_path = 'State_PublicSchools_Rank.json'

# %%
uniRank_df=pd.read_json(uniRank_path)

# %%
uniRank_df
# Out:
#              State  overallRank  qualityRank  safetyRank
# 0    Massachusetts            1            2           1
# 1       New Jersey            2            1          11
# 2      Connecticut            3            3          12
# 3         Virginia            4            7           2
# 4          Vermont            5            6           4
# 5        Minnesota            6            7          23
# 6    New Hampshire            7            9           6
# 7         Nebraska            8           11           7
# 8     North Dakota            9            5          43
# 9          Wyoming           10            8          29
# 10       Wisconsin           11           10          27
# 11        Delaware           12           22           3
# 12        Kentucky           13           13          18
# 13            Iowa           14           12          33
# 14           Maine           15           20           5
# ...

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
stateInitial = pd.DataFrame(list(states.items()),columns = ['State','Initials']) 
stateInitial
# Out:
#                        State Initials
# 0                     Alaska       AK
# 1                    Alabama       AL
# 2                   Arkansas       AR
# 3             American Samoa       AS
# 4                    Arizona       AZ
# 5                 California       CA
# 6                   Colorado       CO
# 7                Connecticut       CT
# 8       District of Columbia       DC
# 9                   Delaware       DE
# 10                   Florida       FL
# 11                   Georgia       GA
# 12                      Guam       GU
# 13                    Hawaii       HI
# 14                      Iowa       IA
# 15                     Idaho       ID
# 16                  Illinois       IL
# 17                   Indiana       IN
# 18                    Kansas       KS
# 19                  Kentucky       KY
# 20                 Louisiana       LA
# 21             Massachusetts       MA
# 22                  Maryland       MD
# 23                     Maine       ME
# ...

# %%
uniStateRank = uniRank_df.merge(stateInitial,on='State',how='left')
uniStateRank
# Out:
#              State  overallRank  qualityRank  safetyRank Initials
# 0    Massachusetts            1            2           1       MA
# 1       New Jersey            2            1          11       NJ
# 2      Connecticut            3            3          12       CT
# 3         Virginia            4            7           2       VA
# 4          Vermont            5            6           4       VT
# 5        Minnesota            6            7          23       MN
# 6    New Hampshire            7            9           6       NH
# 7         Nebraska            8           11           7       NE
# 8     North Dakota            9            5          43       ND
# 9          Wyoming           10            8          29       WY
# 10       Wisconsin           11           10          27       WI
# 11        Delaware           12           22           3       DE
# 12        Kentucky           13           13          18       KY
# ...
