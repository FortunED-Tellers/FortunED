# %%
from pprint import pprint
import pandas as pd

# %%
file = pd.read_csv("major_degree_industry_job_all.csv")

file
# Out:
#                        major_category  \
# 0             Computers & Mathematics
# 1             Computers & Mathematics
# 2             Computers & Mathematics
# 3             Computers & Mathematics
# 4             Computers & Mathematics
# ...                               ...
# 4737  Agriculture & Natural Resources
# 4738  Agriculture & Natural Resources
# 4739  Agriculture & Natural Resources
# 4740  Agriculture & Natural Resources
# 4741  Agriculture & Natural Resources
#
#                                                 major  \
# 0                    MATHEMATICS AND COMPUTER SCIENCE
# 1          COMPUTER NETWORKING AND TELECOMMUNICATIONS
# 2                    COMPUTER AND INFORMATION SYSTEMS
# 3                                    COMPUTER SCIENCE
# 4     COMPUTER ADMINISTRATION MANAGEMENT AND SECURITY
# ...                                               ...
# 4737            AGRICULTURE PRODUCTION AND MANAGEMENT
# 4738                        MISCELLANEOUS AGRICULTURE
# ...

# %%
file.to_json(r"majors_to_jobs.json",orient='records')

# %%
import json

with open('majors_to_jobs.json') as f:
    data = json.load(f)

data
# Out:
# [{'major_category': 'Computers & Mathematics',
#   'major': 'MATHEMATICS AND COMPUTER SCIENCE',
#   'occ_industry': 'Computer and Mathematical Occupations',
#   'occ_title': 'Actuaries',
#   'degree_required': "Bachelor's degree",
#   'work_exp_required': 'None',
#   'total': 7184,
#   'employed': 5874,
#   'emp_full_time_year_round': 5039,
#   'unemployed': 150,
#   'unemployment_rate': 0.024900398,
#   'p25th': 53000,
#   'median': 92000,
#   'p75th': 136000.0},
#  {'major_category': 'Computers & Mathematics',
#   'major': 'COMPUTER NETWORKING AND TELECOMMUNICATIONS',
#   'occ_industry': 'Computer and Mathematical Occupations',
#   'occ_title': 'Actuaries',
#   'degree_required': "Bachelor's degree",
#   'work_exp_required': 'None',
#   'total': 51771,
#   'employed': 44071,
#   'emp_full_time_year_round': 35954,
#   'unemployed': 2748,
#   'unemployment_rate': 0.05869412,
#   'p25th': 36000,
#   'median': 55000,
#   'p75th': 80000.0},
# ...
